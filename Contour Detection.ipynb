# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('Images/IE.png',0)
plt.imshow(img,cmap='gray')

# %%
img.shape
# Out:
# (652, 1080)

# %%
# Finding both internal and external contours usong cv2.RETR_CCOMP

contours,hierarchy = cv2.findContours(img,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

# %%
type(contours)
# Out:
# list

# %%
len(contours)
# Out:
# 22

# %%
type(hierarchy)
# Out:
# numpy.ndarray

# %%
hierarchy
# Out:
# array([[[ 4, -1,  1, -1],
#         [ 2, -1, -1,  0],
#         [ 3,  1, -1,  0],
#         [-1,  2, -1,  0],
#         [21,  0,  5, -1],
#         [ 6, -1, -1,  4],
#         [ 7,  5, -1,  4],
#         [ 8,  6, -1,  4],
#         [ 9,  7, -1,  4],
#         [10,  8, -1,  4],
#         [11,  9, -1,  4],
#         [12, 10, -1,  4],
#         [13, 11, -1,  4],
#         [14, 12, -1,  4],
#         [15, 13, -1,  4],
#         [16, 14, -1,  4],
#         [17, 15, -1,  4],
#         [18, 16, -1,  4],
#         [19, 17, -1,  4],
#         [20, 18, -1,  4],
#         [-1, 19, -1,  4],
#         [-1,  4, -1, -1]]], dtype=int32)

# %%
external_contours = np.zeros(img.shape)
external_contours
plt.imshow(external_contours,cmap='gray')

# %%
for i in range(len(contours)):
    #EXTERNAL
    if hierarchy[0][i][3] == -1:
        cv2.drawContours(external_contours,contours,i,255,-1)
plt.imshow(external_contours,cmap='gray')

# %%
internal_contours = np.zeros(img.shape)
external_contours
plt.imshow(external_contours,cmap='gray')
# Out:
#   File "<ipython-input-56-54b9aa178105>", line 1
#     set([contours[0][i][0] for i in len(contours[0]))
#                                                     ^
# SyntaxError: invalid syntax

# %%
contours
# Out:
# [array([[[236,  35]],
#
#         [[236,  36]],
#
#         [[237,  36]],
#
#         [[237,  35]]], dtype=int32), array([[[  0,   0]],
#
#         [[  0, 167]],
#
#         [[299, 167]],
#
#         [[299,   0]]], dtype=int32), array([[[273, 164]],
#
#         [[274, 163]],
#
#         [[275, 164]],
#
#         [[274, 165]]], dtype=int32), array([[[165, 129]],
#
#         [[166, 128]],
#
#         [[167, 129]],
#
#         [[166, 130]]], dtype=int32), array([[[162, 129]],
#
#         [[163, 128]],
#
#         [[164, 129]],
#
#         [[163, 130]]], dtype=int32), array([[[160, 129]],
#
#         [[161, 128]],
#
#         [[162, 129]],
#
#         [[161, 130]]], dtype=int32), array([[[143, 129]],
#
#         [[144, 128]],
#
#         [[145, 129]],
#
#         [[144, 130]]], dtype=int32), array([[[144, 128]],
#
#         [[145, 127]],
#
#         [[146, 128]],
#
#         [[145, 129]]], dtype=int32), array([[[139, 128]],
#
#         [[140, 127]],
#
#         [[142, 127]],
#
#         [[143, 128]],
#
#         [[143, 129]],
#
#         [[144, 130]],
#
#         [[143, 131]],
#
#         [[142, 131]],
#
#         [[141, 130]],
#
#         [[141, 129]],
#
#         [[140, 129]]], dtype=int32), array([[[143, 126]],
#
#         [[144, 125]],
#
#         [[145, 126]],
#
#         [[144, 127]]], dtype=int32), array([[[144, 123]],
#
#         [[145, 122]],
#
#         [[146, 123]],
#
#         [[146, 124]],
#
#         [[147, 124]],
#
#         [[148, 125]],
#
#         [[147, 126]],
#
#         [[147, 127]],
#
#         [[146, 128]],
#
#         [[145, 127]],
#
#         [[145, 126]],
#
#         [[144, 125]]], dtype=int32), array([[[ 34, 123]],
#
#         [[ 35, 122]],
#
#         [[ 36, 122]],
#
#         [[ 37, 123]],
#
#         [[ 36, 124]],
#
#         [[ 35, 124]]], dtype=int32), array([[[ 56, 122]],
#
#         [[ 57, 121]],
#
#         [[ 58, 122]],
#
#         [[ 57, 123]]], dtype=int32), array([[[145, 121]],
#
#         [[146, 120]],
#
#         [[148, 122]],
#
#         [[147, 123]],
#
#         [[146, 123]],
#
#         [[145, 122]]], dtype=int32), array([[[143, 121]],
#
#         [[144, 120]],
#
#         [[145, 121]],
#
#         [[145, 122]],
#
#         [[144, 123]],
#
#         [[143, 122]]], dtype=int32), array([[[244, 120]],
#
#         [[245, 119]],
#
#         [[246, 120]],
#
#         [[245, 121]]], dtype=int32), array([[[144, 120]],
#
#         [[145, 119]],
#
#         [[146, 120]],
#
#         [[145, 121]]], dtype=int32), array([[[263, 119]],
#
#         [[264, 118]],
#
#         [[265, 119]],
#
#         [[265, 120]],
#
#         [[264, 121]],
#
#         [[263, 120]]], dtype=int32), array([[[142, 119]],
#
#         [[143, 118]],
#
#         [[144, 119]],
#
#         [[143, 120]]], dtype=int32), array([[[140, 119]],
#
#         [[141, 118]],
#
#         [[143, 120]],
#
#         [[143, 125]],
#
#         [[142, 126]],
#
#         [[140, 126]],
#
#         [[139, 125]],
#
#         [[139, 121]],
#
#         [[140, 120]]], dtype=int32), array([[[ 58, 119]],
#
#         [[ 59, 118]],
#
#         [[ 60, 118]],
#
#         [[ 61, 119]],
#
#         [[ 61, 121]],
#
#         [[ 60, 122]],
#
#         [[ 58, 122]],
#
#         [[ 57, 121]],
#
#         [[ 57, 120]],
#
#         [[ 58, 119]],
#
#         [[ 59, 120]]], dtype=int32), array([[[165, 118]],
#
#         [[166, 117]],
#
#         [[167, 118]],
#
#         [[166, 119]]], dtype=int32), array([[[160, 118]],
#
#         [[161, 117]],
#
#         [[162, 118]],
#
#         [[161, 119]]], dtype=int32), array([[[143, 118]],
#
#         [[144, 117]],
#
#         [[145, 118]],
#
#         [[144, 119]]], dtype=int32), array([[[141, 118]],
#
#         [[142, 117]],
#
#         [[143, 118]],
#
#         [[142, 119]]], dtype=int32), array([[[ 54, 118]],
#
#         [[ 55, 117]],
#
#         [[ 57, 119]],
#
#         [[ 57, 121]],
#
#         [[ 56, 122]],
#
#         [[ 55, 122]],
#
#         [[ 54, 121]]], dtype=int32), array([[[ 52, 118]],
#
#         [[ 53, 117]],
#
#         [[ 54, 118]],
#
#         [[ 54, 119]],
#
#         [[ 53, 120]],
#
#         [[ 52, 119]]], dtype=int32), array([[[162, 117]],
#
#         [[163, 116]],
#
#         [[164, 116]],
#
#         [[165, 117]],
#
#         [[165, 118]],
#
#         [[166, 119]],
#
#         [[167, 118]],
#
#         [[168, 119]],
#
#         [[168, 121]],
#
#         [[169, 122]],
#
#         [[169, 125]],
#
#         [[168, 126]],
#
#         [[168, 127]],
#
#         [[167, 128]],
#
#         [[160, 128]],
#
#         [[159, 127]],
#
#         [[159, 124]],
#
#         [[158, 123]],
#
#         [[159, 122]],
#
#         [[159, 119]],
#
#         [[160, 118]],
#
#         [[161, 119]],
#
#         [[162, 118]]], dtype=int32), array([[[142, 117]],
#
#         [[143, 116]],
#
#         [[144, 117]],
#
#         [[143, 118]]], dtype=int32), array([[[261, 116]],
#
#         [[262, 115]],
#
#         [[264, 117]],
#
#         [[264, 118]],
#
#         [[263, 119]],
#
#         [[261, 117]]], dtype=int32), array([[[246, 116]],
#
#         [[247, 115]],
#
#         [[248, 116]],
#
#         [[249, 115]],
#
#         [[250, 116]],
#
#         [[250, 117]],
#
#         [[248, 119]],
#
#         [[246, 117]]], dtype=int32), array([[[244, 116]],
#
#         [[245, 115]],
#
#         [[246, 116]],
#
#         [[246, 117]],
#
#         [[247, 118]],
#
#         [[247, 119]],
#
#         [[246, 120]],
#
#         [[244, 118]]], dtype=int32), array([[[241, 116]],
#
#         [[242, 115]],
#
#         [[244, 117]],
#
#         [[244, 119]],
#
#         [[243, 120]],
#
#         [[242, 119]],
#
#         [[242, 118]],
#
#         [[241, 117]]], dtype=int32), array([[[ 62, 115]],
#
#         [[ 63, 116]],
#
#         [[ 63, 117]],
#
#         [[ 61, 119]],
#
#         [[ 60, 118]],
#
#         [[ 60, 117]]], dtype=int32), array([[[270, 113]],
#
#         [[271, 114]],
#
#         [[271, 115]],
#
#         [[269, 117]],
#
#         [[268, 116]],
#
#         [[268, 115]]], dtype=int32), array([[[248, 113]],
#
#         [[249, 112]],
#
#         [[250, 113]],
#
#         [[250, 114]],
#
#         [[249, 115]],
#
#         [[248, 114]]], dtype=int32), array([[[240, 113]],
#
#         [[241, 112]],
#
#         [[242, 113]],
#
#         [[242, 114]],
#
#         [[241, 115]],
#
#         [[240, 114]]], dtype=int32), array([[[263, 111]],
#
#         [[264, 111]],
#
#         [[265, 112]],
#
#         [[265, 114]],
#
#         [[266, 113]],
#
#         [[267, 113]],
#
#         [[268, 114]],
#
#         [[268, 116]],
#
#         [[269, 117]],
#
#         [[269, 119]],
#
#         [[268, 120]],
#
#         [[267, 119]],
#
#         [[267, 118]],
#
#         [[266, 119]],
#
#         [[265, 119]],
#
#         [[264, 118]],
#
#         [[264, 116]],
#
#         [[263, 115]],
#
#         [[263, 114]],
#
#         [[262, 115]],
#
#         [[261, 115]],
#
#         [[260, 114]]], dtype=int32), array([[[244, 111]],
#
#         [[247, 111]],
#
#         [[248, 112]],
#
#         [[247, 113]],
#
#         [[247, 115]],
#
#         [[246, 116]],
#
#         [[245, 115]],
#
#         [[245, 113]],
#
#         [[245, 114]],
#
#         [[244, 115]],
#
#         [[243, 115]],
#
#         [[242, 114]],
#
#         [[242, 113]]], dtype=int32), array([[[241, 112]],
#
#         [[242, 111]],
#
#         [[243, 112]],
#
#         [[242, 113]]], dtype=int32), array([[[ 60, 112]],
#
#         [[ 61, 111]],
#
#         [[ 62, 112]],
#
#         [[ 62, 114]],
#
#         [[ 61, 115]],
#
#         [[ 60, 114]]], dtype=int32), array([[[264, 111]],
#
#         [[265, 110]],
#
#         [[266, 111]],
#
#         [[265, 112]]], dtype=int32), array([[[261, 111]],
#
#         [[262, 110]],
#
#         [[263, 111]],
#
#         [[262, 112]]], dtype=int32), array([[[248, 111]],
#
#         [[249, 110]],
#
#         [[250, 111]],
#
#         [[249, 112]]], dtype=int32), array([[[242, 111]],
#
#         [[243, 110]],
#
#         [[244, 111]],
#
#         [[243, 112]]], dtype=int32), array([[[ 58, 111]],
#
#         [[ 59, 110]],
#
#         [[ 60, 110]],
#
#         [[ 61, 111]],
#
#         [[ 59, 113]],
#
#         [[ 58, 112]]], dtype=int32), array([[[ 56, 111]],
#
#         [[ 57, 110]],
#
#         [[ 58, 111]],
#
#         [[ 58, 112]],
#
#         [[ 59, 113]],
#
#         [[ 59, 114]],
#
#         [[ 60, 114]],
#
#         [[ 61, 115]],
#
#         [[ 61, 116]],
#
#         [[ 60, 117]],
#
#         [[ 59, 117]],
#
#         [[ 59, 118]],
#
#         [[ 58, 119]],
#
#         [[ 57, 119]],
#
#         [[ 56, 118]],
#
#         [[ 56, 117]],
#
#         [[ 57, 116]],
#
#         [[ 57, 115]],
#
#         [[ 56, 114]]], dtype=int32), array([[[ 54, 111]],
#
#         [[ 55, 110]],
#
#         [[ 56, 111]],
#
#         [[ 56, 115]],
#
#         [[ 55, 116]],
#
#         [[ 53, 116]],
#
#         [[ 52, 115]],
#
#         [[ 52, 114]],
#
#         [[ 54, 112]]], dtype=int32), array([[[ 34, 111]],
#
#         [[ 35, 110]],
#
#         [[ 36, 111]],
#
#         [[ 37, 111]],
#
#         [[ 38, 110]],
#
#         [[ 40, 112]],
#
#         [[ 40, 113]],
#
#         [[ 41, 114]],
#
#         [[ 40, 115]],
#
#         [[ 40, 117]],
#
#         [[ 41, 118]],
#
#         [[ 41, 119]],
#
#         [[ 40, 120]],
#
#         [[ 40, 121]],
#
#         [[ 39, 122]],
#
#         [[ 38, 122]],
#
#         [[ 37, 123]],
#
#         [[ 36, 122]],
#
#         [[ 36, 120]],
#
#         [[ 34, 120]],
#
#         [[ 35, 120]],
#
#         [[ 36, 121]],
#
#         [[ 35, 122]],
#
#         [[ 33, 122]],
#
#         [[ 32, 121]],
#
#         [[ 32, 120]],
#
#         [[ 30, 118]],
#
#         [[ 30, 114]],
#
#         [[ 31, 113]],
#
#         [[ 31, 112]],
#
#         [[ 32, 111]]], dtype=int32), array([[[266, 110]],
#
#         [[267, 109]],
#
#         [[269, 109]],
#
#         [[270, 110]],
#
#         [[270, 112]],
#
#         [[269, 113]],
#
#         [[268, 113]],
#
#         [[267, 112]],
#
#         [[268, 111]],
#
#         [[267, 112]],
#
#         [[266, 111]]], dtype=int32), array([[[262, 110]],
#
#         [[263, 109]],
#
#         [[264, 109]],
#
#         [[265, 110]],
#
#         [[264, 111]],
#
#         [[263, 111]]], dtype=int32), array([[[241, 110]],
#
#         [[242, 109]],
#
#         [[243, 110]],
#
#         [[242, 111]]], dtype=int32), array([[[ 36, 110]],
#
#         [[ 37, 109]],
#
#         [[ 38, 110]],
#
#         [[ 37, 111]]], dtype=int32), array([[[ 33, 110]],
#
#         [[ 34, 109]],
#
#         [[ 35, 110]],
#
#         [[ 34, 111]]], dtype=int32), array([[[264, 109]],
#
#         [[265, 108]],
#
#         [[266, 108]],
#
#         [[267, 109]],
#
#         [[266, 110]],
#
#         [[265, 110]]], dtype=int32), array([[[243, 109]],
#
#         [[244, 108]],
#
#         [[245, 109]],
#
#         [[244, 110]]], dtype=int32), array([[[245, 108]],
#
#         [[246, 107]],
#
#         [[247, 108]],
#
#         [[247, 109]],
#
#         [[248, 109]],
#
#         [[249, 110]],
#
#         [[248, 111]],
#
#         [[245, 111]],
#
#         [[244, 110]],
#
#         [[245, 109]]], dtype=int32), array([[[69, 50]],
#
#         [[70, 49]],
#
#         [[71, 49]],
#
#         [[72, 50]],
#
#         [[71, 51]],
#
#         [[70, 51]]], dtype=int32), array([[[52, 50]],
#
#         [[53, 49]],
#
#         [[54, 50]],
#
#         [[53, 51]]], dtype=int32), array([[[49, 50]],
#
#         [[50, 49]],
#
#         [[51, 50]],
#
#         [[50, 51]]], dtype=int32), array([[[71, 49]],
#
#         [[72, 48]],
#
#         [[73, 49]],
#
#         [[72, 50]]], dtype=int32), array([[[53, 49]],
#
#         [[54, 48]],
#
#         [[55, 49]],
#
#         [[54, 50]]], dtype=int32), array([[[50, 49]],
#
#         [[51, 48]],
#
#         [[52, 48]],
#
#         [[53, 49]],
#
#         [[52, 50]],
#
#         [[51, 50]]], dtype=int32), array([[[160,  48]],
#
#         [[161,  47]],
#
#         [[162,  48]],
#
#         [[161,  49]]], dtype=int32), array([[[140,  48]],
#
#         [[141,  47]],
#
#         [[142,  48]],
#
#         [[141,  49]]], dtype=int32), array([[[72, 48]],
#
#         [[73, 47]],
#
#         [[74, 48]],
#
#         [[73, 49]]], dtype=int32), array([[[69, 48]],
#
#         [[70, 47]],
#
#         [[71, 48]],
#
#         [[70, 49]]], dtype=int32), array([[[48, 48]],
#
#         [[49, 47]],
#
#         [[50, 48]],
#
#         [[50, 49]],
#
#         [[49, 50]],
#
#         [[48, 49]]], dtype=int32), array([[[73, 47]],
#
#         [[74, 46]],
#
#         [[75, 47]],
#
#         [[74, 48]]], dtype=int32), array([[[66, 47]],
#
#         [[67, 46]],
#
#         [[70, 49]],
#
#         [[68, 51]],
#
#         [[67, 50]],
#
#         [[67, 49]],
#
#         [[66, 48]]], dtype=int32), array([[[52, 47]],
#
#         [[53, 46]],
#
#         [[55, 46]],
#
#         [[56, 47]],
#
#         [[55, 48]],
#
#         [[54, 48]],
#
#         [[53, 49]],
#
#         [[52, 48]]], dtype=int32), array([[[49, 46]],
#
#         [[50, 45]],
#
#         [[51, 45]],
#
#         [[52, 46]],
#
#         [[52, 47]],
#
#         [[51, 48]],
#
#         [[50, 48]],
#
#         [[49, 47]]], dtype=int32), array([[[161,  45]],
#
#         [[162,  44]],
#
#         [[163,  44]],
#
#         [[164,  45]],
#
#         [[163,  46]],
#
#         [[163,  47]],
#
#         [[162,  48]],
#
#         [[161,  47]]], dtype=int32), array([[[155,  44]],
#
#         [[156,  43]],
#
#         [[157,  44]],
#
#         [[157,  45]],
#
#         [[156,  46]],
#
#         [[155,  45]]], dtype=int32), array([[[139,  43]],
#
#         [[140,  43]],
#
#         [[142,  45]],
#
#         [[142,  44]],
#
#         [[143,  43]],
#
#         [[145,  45]],
#
#         [[142,  48]],
#
#         [[141,  47]],
#
#         [[138,  47]],
#
#         [[137,  46]],
#
#         [[137,  45]]], dtype=int32), array([[[136,  44]],
#
#         [[137,  43]],
#
#         [[138,  44]],
#
#         [[137,  45]]], dtype=int32), array([[[73, 44]],
#
#         [[74, 43]],
#
#         [[75, 44]],
#
#         [[74, 45]]], dtype=int32), array([[[234,  43]],
#
#         [[235,  42]],
#
#         [[236,  43]],
#
#         [[235,  44]]], dtype=int32), array([[[162,  43]],
#
#         [[163,  42]],
#
#         [[164,  43]],
#
#         [[163,  44]]], dtype=int32), array([[[160,  43]],
#
#         [[161,  42]],
#
#         [[162,  43]],
#
#         [[162,  44]],
#
#         [[161,  45]],
#
#         [[160,  44]]], dtype=int32), array([[[54, 43]],
#
#         [[55, 42]],
#
#         [[56, 43]],
#
#         [[55, 44]]], dtype=int32), array([[[259,  42]],
#
#         [[260,  41]],
#
#         [[261,  42]],
#
#         [[260,  43]]], dtype=int32), array([[[236,  42]],
#
#         [[237,  41]],
#
#         [[238,  42]],
#
#         [[237,  43]]], dtype=int32), array([[[233,  42]],
#
#         [[234,  41]],
#
#         [[235,  42]],
#
#         [[234,  43]]], dtype=int32), array([[[231,  42]],
#
#         [[232,  41]],
#
#         [[233,  42]],
#
#         [[232,  43]]], dtype=int32), array([[[158,  41]],
#
#         [[160,  43]],
#
#         [[160,  45]],
#
#         [[159,  46]],
#
#         [[160,  47]],
#
#         [[160,  48]],
#
#         [[159,  49]],
#
#         [[158,  48]],
#
#         [[157,  48]],
#
#         [[156,  47]],
#
#         [[156,  46]],
#
#         [[157,  45]],
#
#         [[157,  44]],
#
#         [[156,  43]]], dtype=int32), array([[[143,  42]],
#
#         [[144,  41]],
#
#         [[145,  42]],
#
#         [[145,  43]],
#
#         [[144,  44]],
#
#         [[143,  43]]], dtype=int32), array([[[66, 42]],
#
#         [[67, 41]],
#
#         [[68, 42]],
#
#         [[67, 43]]], dtype=int32), array([[[235,  41]],
#
#         [[236,  40]],
#
#         [[237,  41]],
#
#         [[236,  42]]], dtype=int32), array([[[232,  41]],
#
#         [[233,  40]],
#
#         [[234,  41]],
#
#         [[233,  42]]], dtype=int32), array([[[229,  41]],
#
#         [[230,  40]],
#
#         [[231,  40]],
#
#         [[232,  41]],
#
#         [[231,  42]],
#
#         [[230,  42]]], dtype=int32), array([[[155,  41]],
#
#         [[156,  40]],
#
#         [[157,  41]],
#
#         [[157,  42]],
#
#         [[156,  43]],
#
#         [[155,  42]]], dtype=int32), array([[[253,  40]],
#
#         [[254,  39]],
#
#         [[255,  40]],
#
#         [[254,  41]]], dtype=int32), array([[[236,  40]],
#
#         [[237,  39]],
#
#         [[238,  39]],
#
#         [[239,  40]],
#
#         [[238,  41]],
#
#         [[237,  41]]], dtype=int32), array([[[72, 39]],
#
#         [[73, 40]],
#
#         [[73, 41]],
#
#         [[74, 42]],
#
#         [[73, 43]],
#
#         [[72, 43]],
#
#         [[70, 41]]], dtype=int32), array([[[67, 40]],
#
#         [[68, 39]],
#
#         [[70, 41]],
#
#         [[70, 42]],
#
#         [[71, 43]],
#
#         [[69, 45]],
#
#         [[70, 45]],
#
#         [[72, 43]],
#
#         [[73, 44]],
#
#         [[73, 45]],
#
#         [[74, 46]],
#
#         [[73, 47]],
#
#         [[70, 47]],
#
#         [[69, 48]],
#
#         [[66, 45]],
#
#         [[66, 44]],
#
#         [[67, 43]],
#
#         [[68, 43]],
#
#         [[68, 42]],
#
#         [[67, 41]]], dtype=int32), array([[[52, 40]],
#
#         [[53, 39]],
#
#         [[55, 41]],
#
#         [[55, 42]],
#
#         [[54, 43]],
#
#         [[52, 41]]], dtype=int32), array([[[231,  39]],
#
#         [[232,  38]],
#
#         [[233,  39]],
#
#         [[232,  40]]], dtype=int32), array([[[163,  38]],
#
#         [[164,  39]],
#
#         [[164,  40]],
#
#         [[163,  41]],
#
#         [[163,  42]],
#
#         [[162,  43]],
#
#         [[161,  42]],
#
#         [[161,  40]]], dtype=int32), array([[[142,  38]],
#
#         [[143,  39]],
#
#         [[144,  39]],
#
#         [[145,  40]],
#
#         [[143,  42]],
#
#         [[142,  41]],
#
#         [[140,  43]],
#
#         [[138,  43]],
#
#         [[137,  42]],
#
#         [[137,  41]],
#
#         [[138,  40]],
#
#         [[140,  40]]], dtype=int32), array([[[69, 39]],
#
#         [[70, 38]],
#
#         [[71, 39]],
#
#         [[71, 40]],
#
#         [[70, 41]],
#
#         [[69, 40]]], dtype=int32), array([[[50, 39]],
#
#         [[51, 38]],
#
#         [[52, 38]],
#
#         [[53, 39]],
#
#         [[52, 40]],
#
#         [[52, 42]],
#
#         [[53, 42]],
#
#         [[55, 44]],
#
#         [[55, 45]],
#
#         [[54, 46]],
#
#         [[53, 45]],
#
#         [[52, 45]],
#
#         [[51, 44]],
#
#         [[49, 46]],
#
#         [[48, 45]],
#
#         [[48, 44]],
#
#         [[50, 42]],
#
#         [[50, 41]],
#
#         [[50, 42]],
#
#         [[49, 43]],
#
#         [[48, 43]],
#
#         [[47, 42]],
#
#         [[48, 41]],
#
#         [[48, 40]],
#
#         [[49, 39]]], dtype=int32), array([[[229,  37]],
#
#         [[230,  36]],
#
#         [[231,  37]],
#
#         [[231,  39]],
#
#         [[230,  40]],
#
#         [[229,  40]],
#
#         [[228,  39]],
#
#         [[229,  38]]], dtype=int32), array([[[160,  37]],
#
#         [[161,  36]],
#
#         [[163,  38]],
#
#         [[161,  40]],
#
#         [[160,  39]]], dtype=int32), array([[[159,  36]],
#
#         [[160,  37]],
#
#         [[160,  39]],
#
#         [[161,  40]],
#
#         [[161,  41]],
#
#         [[160,  42]],
#
#         [[159,  41]],
#
#         [[157,  41]],
#
#         [[156,  40]],
#
#         [[157,  39]],
#
#         [[157,  38]]], dtype=int32), array([[[140,  36]],
#
#         [[142,  36]],
#
#         [[143,  37]],
#
#         [[142,  38]],
#
#         [[141,  38]],
#
#         [[139,  40]],
#
#         [[137,  40]],
#
#         [[136,  39]],
#
#         [[137,  38]],
#
#         [[138,  38]]], dtype=int32), array([[[228,  35]],
#
#         [[229,  34]],
#
#         [[230,  35]],
#
#         [[230,  36]],
#
#         [[229,  37]],
#
#         [[228,  36]]], dtype=int32), array([[[234,  30]],
#
#         [[235,  29]],
#
#         [[236,  30]],
#
#         [[236,  31]],
#
#         [[237,  30]],
#
#         [[238,  31]],
#
#         [[238,  33]],
#
#         [[239,  33]],
#
#         [[240,  34]],
#
#         [[240,  37]],
#
#         [[239,  38]],
#
#         [[238,  38]],
#
#         [[235,  41]],
#
#         [[234,  41]],
#
#         [[233,  40]],
#
#         [[234,  39]],
#
#         [[234,  38]],
#
#         [[233,  37]],
#
#         [[231,  37]],
#
#         [[230,  36]],
#
#         [[230,  35]],
#
#         [[229,  34]],
#
#         [[229,  31]],
#
#         [[230,  30]],
#
#         [[231,  31]],
#
#         [[231,  33]],
#
#         [[232,  34]],
#
#         [[233,  34]],
#
#         [[234,  33]],
#
#         [[232,  33]],
#
#         [[231,  32]],
#
#         [[231,  31]],
#
#         [[232,  30]],
#
#         [[233,  31]],
#
#         [[234,  31]]], dtype=int32), array([[[232,  30]],
#
#         [[233,  29]],
#
#         [[234,  30]],
#
#         [[233,  31]]], dtype=int32), array([[[230,  30]],
#
#         [[231,  29]],
#
#         [[232,  30]],
#
#         [[231,  31]]], dtype=int32), array([[[260,  29]],
#
#         [[261,  28]],
#
#         [[263,  30]],
#
#         [[262,  31]],
#
#         [[261,  31]],
#
#         [[260,  30]]], dtype=int32), array([[[236,  29]],
#
#         [[237,  28]],
#
#         [[238,  29]],
#
#         [[237,  30]]], dtype=int32), array([[[233,  29]],
#
#         [[234,  28]],
#
#         [[235,  29]],
#
#         [[234,  30]]], dtype=int32), array([[[231,  29]],
#
#         [[232,  28]],
#
#         [[233,  29]],
#
#         [[232,  30]]], dtype=int32), array([[[257,  28]],
#
#         [[258,  27]],
#
#         [[260,  27]],
#
#         [[261,  28]],
#
#         [[260,  29]],
#
#         [[260,  30]],
#
#         [[261,  31]],
#
#         [[262,  31]],
#
#         [[263,  30]],
#
#         [[264,  31]],
#
#         [[264,  34]],
#
#         [[265,  35]],
#
#         [[264,  36]],
#
#         [[264,  39]],
#
#         [[261,  42]],
#
#         [[260,  41]],
#
#         [[260,  40]],
#
#         [[260,  41]],
#
#         [[259,  42]],
#
#         [[258,  41]],
#
#         [[258,  40]],
#
#         [[258,  41]],
#
#         [[259,  42]],
#
#         [[258,  43]],
#
#         [[256,  43]],
#
#         [[254,  41]],
#
#         [[255,  40]],
#
#         [[256,  40]],
#
#         [[255,  39]],
#
#         [[254,  39]],
#
#         [[253,  38]],
#
#         [[253,  37]],
#
#         [[254,  36]],
#
#         [[255,  36]],
#
#         [[255,  35]],
#
#         [[254,  35]],
#
#         [[254,  36]],
#
#         [[253,  37]],
#
#         [[252,  36]],
#
#         [[252,  34]],
#
#         [[253,  33]],
#
#         [[253,  31]],
#
#         [[254,  30]],
#
#         [[255,  31]],
#
#         [[254,  30]],
#
#         [[255,  29]],
#
#         [[256,  29]],
#
#         [[258,  31]],
#
#         [[257,  30]],
#
#         [[258,  29]]], dtype=int32), array([[[255,  28]],
#
#         [[256,  27]],
#
#         [[257,  28]],
#
#         [[256,  29]]], dtype=int32), array([[[232,  28]],
#
#         [[233,  27]],
#
#         [[234,  28]],
#
#         [[233,  29]]], dtype=int32)]
